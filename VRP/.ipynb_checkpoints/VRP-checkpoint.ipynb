# %% [markdown]
# # Vehicle Routing Problem (VRP)
#
# ![image.png](attachment:image.png)

# %%
import gurobipy
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# [https://www.gurobi.com/](https://www.gurobi.com/) A really good optimization software used by companies like toyota, mercedes, basf etc.

# %% [markdown]
# ## Generating problem instance...

# %%
#Input Data
rnd = np.random
n = 10
xc = rnd.rand(n+1)*200
yc = rnd.rand(n+1)*100
N = [i for i in range(1,n+1)]
V = [0] + N
A = [(i,j) for i in V for j in V if i != j]
c = {(i,j): np.hypot(xc[i]-xc[j], yc[i]-yc[j]) for i,j in A}
Q = 50
q = {i: rnd.randint(10,30) for i in N}
plt.figure(figsize=(10, 6), dpi=80)
plt.plot(xc[0], yc[0], c='r', marker='s')
plt.scatter(xc[1:], yc[1:], c = 'b')


for i, txt in enumerate(q):
    plt.annotate(q[txt], (xc[i]+3, yc[i]+3))

# %% [markdown]
# ## Building the mathematical model

# %%
from gurobipy import Model, GRB, quicksum

# %%
mdl = Model("CVRP")
mdl.setParam('TimeLimit', 30)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-03-22
# Set parameter TimeLimit to value 30

# %%
x = mdl.addVars(A, vtype=GRB.BINARY)
u = mdl.addVars(N, vtype=GRB.CONTINUOUS)

# %%
mdl.modelSense = GRB.MINIMIZE

# %%
mdl.setObjective(quicksum(x[a]*c[a] for a in A))

# %% [markdown]
# min! $\sum_{i,j \in \mathcal{A}}  c_{i,j} \cdot x_{i,j}$

# %% [markdown]
# $\sum_{j \in \mathcal{V}, j \neq i}  x_{i,j} = 1 \;\; \forall i \in N $

# %% [markdown]
# $\sum_{j \in \mathcal{V}, j \neq i}  x_{i,j} = 1 \;\; \forall j \in N $

# %% [markdown]
# if $x_{i,j} \rightarrow u_i + q_j = u_j \,\,\, \forall  k \in \mathcal{K} ,t \in \mathcal{T}$

# %% [markdown]
# $q_i \leq u_i \leq Q \; \forall i \in N$

# %% [markdown]
# $x_{i,j} \in {0,1}$

# %%
mdl.addConstrs(quicksum(x[i,j] for j in V if j!=i)== 1 for i in N);
mdl.addConstrs(quicksum(x[i,j] for i in V if j!=i)== 1 for j in N);
mdl.addConstrs((x[i,j] == 1) >> (u[i] + q[i] == u[j])
              for i,j in A if i!=0 and j!=0);
mdl.addConstrs(u[i] >= q[i] for  i in N);
mdl.addConstrs(u[i] <= Q for i in N);

# %% [markdown]
# ## Perform Solution procedure with gurobi

# %%
mdl.optimize()
# Out:
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 40 rows, 120 columns and 220 nonzeros
# Model fingerprint: 0x982c480b
# Model has 90 general constraints
# Variable types: 10 continuous, 110 integer (110 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   GenCon rhs range [1e+01, 3e+01]
#   GenCon coe range [1e+00, 1e+00]
# Presolve added 99 rows and 0 columns
# Presolve removed 0 rows and 18 columns
# Presolve time: 0.06s
# Presolved: 139 rows, 102 columns, 1119 nonzeros
# Variable types: 12 continuous, 90 integer (90 binary)
# Found heuristic solution: objective 867.7973606
#
# Root relaxation: objective 6.445260e+02, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  644.52602    0    6  867.79736  644.52602  25.7%     -    0s
# H    0     0                     823.0001556  644.52602  21.7%     -    0s
# H    0     0                     727.2825927  644.52602  11.4%     -    0s
#      0     0  654.11947    0    6  727.28259  654.11947  10.1%     -    0s
#      0     0  675.94570    0    9  727.28259  675.94570  7.06%     -    0s
#      0     0  675.94570    0   10  727.28259  675.94570  7.06%     -    0s
#      0     0  676.40049    0   10  727.28259  676.40049  7.00%     -    0s
#      0     0  678.73604    0   11  727.28259  678.73604  6.68%     -    0s
#      0     0  678.74168    0   13  727.28259  678.74168  6.67%     -    0s
#      0     0  681.93283    0   10  727.28259  681.93283  6.24%     -    0s
#      0     0  684.73815    0   11  727.28259  684.73815  5.85%     -    0s
#      0     0  686.68292    0    8  727.28259  686.68292  5.58%     -    0s
#      0     0  686.68292    0    8  727.28259  686.68292  5.58%     -    0s
#      0     0  695.49934    0    8  727.28259  695.49934  4.37%     -    0s
#      0     0  702.94289    0    7  727.28259  702.94289  3.35%     -    0s
#      0     0  702.94289    0    7  727.28259  702.94289  3.35%     -    0s
#      0     0  702.94289    0    7  727.28259  702.94289  3.35%     -    0s
#      0     0     cutoff    0       727.28259  727.28259  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Cover: 1
#   Implied bound: 3
#   MIR: 2
#   StrongCG: 1
#   GUB cover: 2
#   Zero half: 2
#   RLT: 2
#   Relax-and-lift: 2
#
# Explored 1 nodes (239 simplex iterations) in 0.42 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 727.283 823 867.797
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.272825927040e+02, best bound 7.272825927040e+02, gap 0.0000%

# %%
active_arcs = [a for a in A if x[a].x > 0.99]

#Coloring every unique route with a different color

def FindEdgeByStartingNode(Node, li):
    for e in li:
        if(e[0] == Node):
            return e

def GetRouteRemoveEdgesFromLi(startingEdge, li): 
    x = startingEdge
    tour = []
    tour.append(startingEdge) 
    while(True):
        x = FindEdgeByStartingNode(x[1], li)
        tour.append(x)
        
        if(x[1] == 0):
            break            
        #li.pop(li.index(x))   
    return tour

numberOfRoutes = 0
for e in active_arcs:
    if(e[0] == 0):
        numberOfRoutes+=1
routes = []

for i in range(0,numberOfRoutes+1):
    routes.append(GetRouteRemoveEdgesFromLi(active_arcs[i],active_arcs))
    #we get error message when amoutn of routes is less than 3
    
active_arcs = [a for a in A if x[a].x > 0.99]

# %%
color = ['tab:blue','tab:orange','tab:green','tab:red','tab:purple','tab:brown','tab:pink','tab:gray','tab:olive','tab:cyan']

plt.figure(figsize=(10, 6), dpi=80) 
for idx, route in enumerate(routes):
    for i,j in route:
        plt.plot([xc[i], xc[j]], [yc[i], yc[j]], c=f'{color[idx]}', zorder=0)
  
plt.plot(xc[0], yc[0], c='r', marker='s')
plt.scatter(xc[1:], yc[1:], c='b')

for i, txt in enumerate(q):
    plt.annotate(txt, (xc[i]+3, yc[i]+3))

# %% [markdown]
# # Things to consider when thinking about planning of intralogistic processes
