# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import gurobipy
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# [https://www.gurobi.com/](https://www.gurobi.com/) A really good optimization software used by companies like toyota, mercedes, basf etc.

# %% [markdown]
# ## Generating problem instance...

# %%
#Input Data
rnd = np.random
n = 20
xc = rnd.rand(n+1)*200
yc = rnd.rand(n+1)*100
N = [i for i in range(1,n+1)]
V = [0] + N
A = [(i,j) for i in V for j in V if i != j]
c = {(i,j): np.hypot(xc[i]-xc[j], yc[i]-yc[j]) for i,j in A}
Q = 50
q = {i: rnd.randint(1,10) for i in N}
plt.figure(figsize=(10, 6), dpi=80)
plt.plot(xc[0], yc[0], c='r', marker='s')
plt.scatter(xc[1:], yc[1:], c = 'b')


for i, txt in enumerate(q):
    plt.annotate(txt, (xc[i]+3, yc[i]+3))

# %% [markdown]
# ## Building the mathematical model

# %%
from gurobipy import Model, GRB, quicksum

# %%
mdl = Model("CVRP")
mdl.setParam('TimeLimit', 30)
# Out:
# Set parameter TimeLimit to value 30

# %%
x = mdl.addVars(A, vtype=GRB.BINARY)
u = mdl.addVars(N, vtype=GRB.CONTINUOUS)

# %%
mdl.modelSense = GRB.MINIMIZE

# %%
mdl.setObjective(quicksum(x[a]*c[a] for a in A))

# %% [markdown]
# min! $\sum_{i,j \in \mathcal{A}}  c_{i,j} \cdot d_{i,j}$

# %% [markdown]
# $\sum_{j \in \mathcal{V}, j \neq i}  x_{i,j} = 1 \;\; \forall i \in N $

# %% [markdown]
# $\sum_{j \in \mathcal{V}, j \neq i}  x_{i,j} = 1 \;\; \forall j \in N $

# %% [markdown]
# if $x_{i,j} \rightarrow u_i + q_j = u_j \,\,\, \forall  k \in \mathcal{K} ,t \in \mathcal{T}$

# %% [markdown]
# $q_i \leq u_i \leq Q \; \forall i \in N$

# %% [markdown]
# $x_{i,j} \in {0,1}$

# %%
mdl.addConstrs(quicksum(x[i,j] for j in V if j!=i)== 1 for i in N);
mdl.addConstrs(quicksum(x[i,j] for i in V if j!=i)== 1 for j in N);
mdl.addConstrs((x[i,j] == 1) >> (u[i] + q[i] == u[j])
              for i,j in A if i!=0 and j!=0);
mdl.addConstrs(u[i] >= q[i] for  i in N);
mdl.addConstrs(u[i] <= Q for i in N);

# %% [markdown]
# ## Perform Solution procedure with gurobi

# %%
mdl.optimize()
# Out:
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 80 rows, 440 columns and 840 nonzeros
# Model fingerprint: 0xfeffb183
# Model has 380 general constraints
# Variable types: 20 continuous, 420 integer (420 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   GenCon rhs range [1e+00, 8e+00]
#   GenCon coe range [1e+00, 1e+00]
# Presolve added 730 rows and 100 columns
# Presolve time: 0.08s
# Presolved: 810 rows, 540 columns, 5605 nonzeros
# Variable types: 120 continuous, 420 integer (420 binary)
# Found heuristic solution: objective 2360.5032046
#
# Root relaxation: objective 4.339224e+02, 104 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  433.92240    0   39 2360.50320  433.92240  81.6%     -    0s
# H    0     0                    2084.8551746  433.92240  79.2%     -    0s
# H    0     0                    1138.2435768  433.92240  61.9%     -    0s
# H    0     0                    1109.6178433  433.92240  60.9%     -    0s
#      0     0  454.75810    0   43 1109.61784  454.75810  59.0%     -    0s
# H    0     0                     989.5300559  454.75810  54.0%     -    0s
#      0     0  456.04119    0   41  989.53006  456.04119  53.9%     -    0s
#      0     0  456.04119    0   41  989.53006  456.04119  53.9%     -    0s
#      0     0  456.87267    0   41  989.53006  456.87267  53.8%     -    0s
# H    0     0                     986.7267219  456.87267  53.7%     -    0s
# H    0     0                     972.5104398  456.87267  53.0%     -    0s
# H    0     0                     664.2151104  456.87267  31.2%     -    0s
#      0     0  456.88637    0   43  664.21511  456.88637  31.2%     -    0s
#      0     0  457.19288    0   44  664.21511  457.19288  31.2%     -    0s
#      0     0  457.19288    0   44  664.21511  457.19288  31.2%     -    0s
#      0     0  457.78631    0   38  664.21511  457.78631  31.1%     -    0s
#      0     0  457.78631    0   38  664.21511  457.78631  31.1%     -    0s
#      0     0  457.86936    0   44  664.21511  457.86936  31.1%     -    0s
#      0     0  458.00229    0   44  664.21511  458.00229  31.0%     -    0s
#      0     0  459.67668    0   46  664.21511  459.67668  30.8%     -    0s
#      0     0  459.71792    0   49  664.21511  459.71792  30.8%     -    0s
#      0     0  459.71792    0   49  664.21511  459.71792  30.8%     -    0s
#      0     0  461.62036    0   49  664.21511  461.62036  30.5%     -    0s
#      0     0  462.60974    0   47  664.21511  462.60974  30.4%     -    0s
#      0     0  462.60974    0   47  664.21511  462.60974  30.4%     -    0s
#      0     0  462.60974    0   47  664.21511  462.60974  30.4%     -    0s
#      0     0  462.60974    0   47  664.21511  462.60974  30.4%     -    0s
#      0     0  462.60974    0   47  664.21511  462.60974  30.4%     -    0s
#      0     0  462.60974    0   47  664.21511  462.60974  30.4%     -    0s
#      0     2  464.27801    0   47  664.21511  464.27801  30.1%     -    0s
# H   32    36                     647.9334349  465.42063  28.2%   9.3    0s
# H   71    78                     634.7948027  465.42063  26.7%   6.5    0s
# H  137   122                     560.9528247  465.42063  17.0%   4.7    1s
# H  240   206                     559.0602725  466.19853  16.6%   5.6    1s
#   2787  1616  488.51136   28   31  559.06027  469.22376  16.1%   7.7    5s
# * 2846  1553              82     547.6652689  469.22376  14.3%   7.7    5s
# H 5984  3730                     545.2144576  473.79972  13.1%   8.3    7s
# H 5994  3730                     544.9583653  473.79972  13.1%   8.3    7s
# H 8554  5106                     540.9104974  475.79603  12.0%   8.5    9s
#  10435  6517  487.90848   33   34  540.91050  477.08958  11.8%   8.6   10s
#  17909 10122     cutoff   40       540.91050  481.08408  11.1%   9.0   15s
#  20667 11208  493.93796   35   44  540.91050  482.28183  10.8%   9.2   20s
#  22986 12056  483.58054   41   31  540.91050  482.28183  10.8%   9.2   25s
#  32186 15054  504.32151   61   22  540.91050  482.28183  10.8%   9.0   30s
#
# Cutting planes:
#   Learned: 3
#   Gomory: 20
#   Cover: 30
#   Implied bound: 16
#   Projected implied bound: 9
#   MIR: 11
#   StrongCG: 3
#   Flow cover: 71
#   Inf proof: 3
#   Zero half: 8
#   Relax-and-lift: 8
#
# Explored 32447 nodes (293948 simplex iterations) in 30.02 seconds (17.84 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 10: 540.91 544.958 545.214 ... 972.51
#
# Time limit reached
# Best objective 5.409104973623e+02, best bound 4.822818286202e+02, gap 10.8389%

# %%
active_arcs = [a for a in A if x[a].x > 0.99]

# %%
def findEdgeByStartingNode(Node, li):
    for e in li:
        if(e[0] == Node):
            return e

# %%
def GetRouteRemoveEdgesFromLi(startingEdge, li):
    x = startingEdge
    tour = []
    tour.append(startingEdge)
    
    while(True):
        x = findEdgeByStartingNode(x[1], li)
        tour.append(x)
        
        if(x[1] == 0):
            break
            
        li.pop(li.index(x))
    
    return tour

routes = []

for i in range(0,2):
    routes.append(GetRouteRemoveEdgesFromLi(active_arcs[i],active_arcs))
    #we get error message when amoutn of routes is less than 3
    
active_arcs = [a for a in A if x[a].x > 0.99]

# %%
color = ['tab:blue','tab:orange','tab:green','tab:red','tab:purple','tab:brown','tab:pink','tab:gray','tab:olive','tab:cyan']

plt.figure(figsize=(10, 6), dpi=80) 
for idx, route in enumerate(routes):
    for i,j in route:
        plt.plot([xc[i], xc[j]], [yc[i], yc[j]], c=f'{color[idx]}', zorder=0)
  
plt.plot(xc[0], yc[0], c='r', marker='s')
plt.scatter(xc[1:], yc[1:], c='b')

for i, txt in enumerate(q):
    plt.annotate(txt, (xc[i]+3, yc[i]+3))

# %% [markdown]
# # code graveyard
#
#
# plt.figure(figsize=(10, 6), dpi=80)
# for i,j in active_arcs:
#     plt.plot([xc[i], xc[j]], [yc[i], yc[j]], c='b', zorder=0)
#
# plt.plot(xc[0], yc[0], c='r', marker='s')
# plt.scatter(xc[1:], yc[1:], c='b')
#
# for i, txt in enumerate(q):
#     plt.annotate(txt, (xc[i]+3, yc[i]+3))
