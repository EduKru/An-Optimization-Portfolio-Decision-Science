# %%
import gurobipy
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Vehicle Routing Problem
# ![image.png](attachment:image.png)

# %%
#Input Data
rnd = np.random
rnd.seed(0)
n = 10
xc = rnd.rand(n+1)*200
yc = rnd.rand(n+1)*100

plt.plot(xc[0], yc[0], c='r', marker='s')
plt.scatter(xc[1:], yc[1:], c = 'b')

N = [i for i in range(1,n+1)]
V = [0] + N
A = [(i,j) for i in V for j in V if i != j]
c = {(i,j): np.hypot(xc[i]-xc[j], yc[i]-yc[j]) for i,j in A}
Q = 20
q = {i: rnd.randint(1,10) for i in N}

# %%
from gurobipy import Model, GRB, quicksum

# %%
mdl = Model("CVRP")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-03-22

# %%
x = mdl.addVars(A, vtype=GRB.BINARY)
u = mdl.addVars(N, vtype=GRB.CONTINUOUS)

# %%
mdl.modelSense = GRB.MINIMIZE

# %%
mdl.setObjective(quicksum(x[a]*c[a] for a in A))

# %%
mdl.addConstrs(quicksum(x[i,j] for j in V if j!=i)== 1 for i in N);
mdl.addConstrs(quicksum(x[i,j] for i in V if j!=i)== 1 for j in N);
mdl.addConstrs((x[i,j] == 1) >> (u[i] + q[i] == u[j])
              for i,j in A if i!=0 and j!=0);
mdl.addConstrs(u[i] >= q[i] for  i in N);
mdl.addConstrs(u[i] <= Q for i in N);

# %%
mdl.optimize()
# Out:
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 190 rows, 230 columns and 1630 nonzeros
# Model fingerprint: 0x2a0de853
# Model has 270 general constraints
# Variable types: 10 continuous, 220 integer (220 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   GenCon rhs range [1e+00, 8e+00]
#   GenCon coe range [1e+00, 1e+00]
# Presolve added 28 rows and 0 columns
# Presolve removed 0 rows and 98 columns
# Presolve time: 0.03s
# Presolved: 218 rows, 132 columns, 1301 nonzeros
# Variable types: 42 continuous, 90 integer (90 binary)
# Found heuristic solution: objective 885.6836867
#
# Root relaxation: objective 3.068464e+02, 47 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  306.84636    0   23  885.68369  306.84636  65.4%     -    0s
# H    0     0                     822.0065895  306.84636  62.7%     -    0s
# H    0     0                     549.7381753  306.84636  44.2%     -    0s
# H    0     0                     522.2624080  306.84636  41.2%     -    0s
# H    0     0                     518.7956565  306.84636  40.9%     -    0s
#      0     0  313.39546    0   25  518.79566  313.39546  39.6%     -    0s
# H    0     0                     481.7317889  313.39546  34.9%     -    0s
#      0     0  313.39546    0   25  481.73179  313.39546  34.9%     -    0s
#      0     0  331.45169    0   25  481.73179  331.45169  31.2%     -    0s
# H    0     0                     476.1647238  331.45169  30.4%     -    0s
#      0     0  331.55514    0   27  476.16472  331.55514  30.4%     -    0s
#      0     0  335.29773    0   26  476.16472  335.29773  29.6%     -    0s
#      0     0  342.46535    0   22  476.16472  342.46535  28.1%     -    0s
#      0     0  342.46535    0   22  476.16472  342.46535  28.1%     -    0s
#      0     0  342.47492    0   25  476.16472  342.47492  28.1%     -    0s
#      0     0  344.24307    0   25  476.16472  344.24307  27.7%     -    0s
#      0     0  344.62572    0   27  476.16472  344.62572  27.6%     -    0s
#      0     0  344.62572    0   27  476.16472  344.62572  27.6%     -    0s
#      0     2  344.62572    0   27  476.16472  344.62572  27.6%     -    0s
# *   20    20              10     471.8019086  361.57246  23.4%  13.1    0s
# *   21    20               8     469.7367681  361.57246  23.0%  13.0    0s
# H   74    35                     455.9147547  381.00949  16.4%  11.2    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 1
#   Cover: 3
#   Implied bound: 7
#   MIR: 6
#   Mod-K: 1
#   Relax-and-lift: 1
#
# Explored 830 nodes (8905 simplex iterations) in 0.65 seconds (0.21 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 10: 455.915 469.737 471.802 ... 885.684
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.559147547435e+02, best bound 4.559147547435e+02, gap 0.0000%
