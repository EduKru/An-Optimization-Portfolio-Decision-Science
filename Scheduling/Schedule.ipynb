# %% [markdown]
# # supply chain optimization

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# $$
# (1) \min _{T_{j} ; j=1, \ldots .}\left\{\sum_{j=1}^{J} T_{j}\right\}
# $$
# s.t.
# $$
# \begin{aligned}
# &(2) \;\; 1 \geqslant \sum_{j=1}^{J} y_{m j} \quad \forall m=1, \ldots, M  \\
# &(3) \;\; y_{m j} \in\{0,1\} \quad \forall m=1, \ldots, M ; j=1, \ldots, J \\
# & (4) \;\; 1=\sum_{i=1, i \neq j}^{J+1} x_{j i} \quad \forall j=1, \ldots, J \\
# & (5) \;\;x_{i j} \in\{0,1\} \quad \forall i=1, \ldots, J ; j=1, \ldots, J+1 ; i \neq j \\
# & (6) \;\; 1=\sum_{m=1}^{M} y_{m j}+\sum_{i=1, i \neq j}^{J} x_{i j} \quad \forall j=1, \ldots, J \\
# & (7) \;\; C_{j} \geqslant y_{m j}\left(r_{m}+p_{j}\right) \quad \forall j=1, \ldots, J ; m=1, \ldots, M \\
# & (8) \;\; C_{j} \geqslant C_{i}+p_{j}-q\left(1-x_{i j}\right) \quad \forall i, j=1, \ldots, J ; i \neq j \\
# & (9) \;\; T_{j} \geqslant 0 \quad \forall j=1, \ldots, J \\
# & (10) \;\; T_{j} \geqslant C_{j}-d_{j} \quad \forall j=1, \ldots, J
# \end{aligned}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - (1) objective function
# - (2) at most one job can be selected as a starting job on a machine
# - (3) machine-firstjob-assignment is a binary decision
# - (4) every job has a successor and every job has a predeccessor
# - (5) wheter job j comes before job i or vice versa is a binary decision
# - (6) job can either be a "first job" or a successor not both
# - (7) the completion time of job j ($C_j$) is defined by the ready time of the machine, the and the duration of job j ($p_j$)
# - (8) $C_j$ is defined by $C_i$ if both job j is successor of job i
# - (9)/(10) $T_j$ is the tardiness of a job and is defined by the diff between completion time and demand

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (1) $T_j$:
